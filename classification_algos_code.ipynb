# %% [markdown]
# ## IML Assignment

# %% [markdown]
# ### I have applied the following Classification Models:-
#
# 1. Logistic Regression
# 2. SVM
# 3. Kernal SVM
# 4. Decision Tree Classification
# 5. Random Forest Classification
# 6. Naive Bayes

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Data reading , splitting and scaling

# %%
# reading data
dataset = pd.read_csv('Social_Network_Ads.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

#splitting the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# scaling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ### LOGISTIC REGRESSION RESULTS

# %%
# model fit
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)

#predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
data = {'Model': ['Logistic Regression'], 'Accuracy': [ac_score], 'Error Rate': [error_rate]}
df = pd.DataFrame(data)
# Out:
# The confusion Matrix is:
#  [[57  1]
#  [ 5 17]]
# The accuracy score is:  0.925
# The error_rate is:  0.07499999999999996
# The auc_score is:  0.9764890282131661

# %% [markdown]
# ## SVM

# %%
#model fit
classifier = SVC(kernel = 'linear',probability=True ,random_state = 0)
classifier.fit(x_train, y_train)

# predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
new_row = {'Model': 'SVM', 'Accuracy': ac_score, 'Error Rate': error_rate}
df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# The confusion Matrix is:
#  [[57  1]
#  [ 6 16]]
# The accuracy score is:  0.9125
# The error_rate is:  0.08750000000000002
# The auc_score is:  0.9710031347962382

# %% [markdown]
# ## Kernal SVM

# %%
# reading data
dataset = pd.read_csv('Social_Network_Ads.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

#splitting the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# scaling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# model fit
classifier = SVC(kernel = 'rbf',probability=True, random_state = 0)
classifier.fit(x_train, y_train)

#predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
new_row = {'Model': 'Kernal SVM', 'Accuracy': ac_score, 'Error Rate': error_rate}
df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# The confusion Matrix is:
#  [[55  3]
#  [ 1 21]]
# The accuracy score is:  0.95
# The error_rate is:  0.050000000000000044
# The auc_score is:  0.969435736677116

# %% [markdown]
# ## Decision Tree Classification

# %%
# model fit
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)

# predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
new_row = {'Model': 'Decision Tree', 'Accuracy': ac_score, 'Error Rate': error_rate}
df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# The confusion Matrix is:
#  [[53  5]
#  [ 3 19]]
# The accuracy score is:  0.9
# The error_rate is:  0.09999999999999998
# The auc_score is:  0.8875391849529781

# %% [markdown]
# ## Random Forest Classification

# %%
# model fit
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)

#predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
new_row = {'Model': 'Random Foresrt', 'Accuracy': ac_score, 'Error Rate': error_rate}
df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# The confusion Matrix is:
#  [[54  4]
#  [ 3 19]]
# The accuracy score is:  0.9125
# The error_rate is:  0.08750000000000002
# The auc_score is:  0.975705329153605

# %% [markdown]
# ## Naive Bayes

# %%
classifier = GaussianNB()
classifier.fit(x_train, y_train)

#predictions
y_pred = classifier.predict(x_test)

# Metrics calculation
ac_score = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
probs = classifier.predict_proba(x_test)
fpr, tpr, thresholds = roc_curve(y_test, probs[:, 1])
auc_score = auc(fpr, tpr)
error_rate = 1 - ac_score

print("The confusion Matrix is:\n", cm)
print("The accuracy score is: ", ac_score)
print("The error_rate is: ", error_rate)
print("The auc_score is: ", auc_score)

# plotting in graph
plt.plot(fpr, tpr, label='AUC = {:.4f}'.format(auc_score))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')
plt.legend()
plt.show()

# saving the accuracy and error rate results
new_row = {'Model': 'Naive Bayes', 'Accuracy': ac_score, 'Error Rate': error_rate}
df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# The confusion Matrix is:
#  [[55  3]
#  [ 4 18]]
# The accuracy score is:  0.9125
# The error_rate is:  0.08750000000000002
# The auc_score is:  0.9843260188087775

# %% [markdown]
# ### Comparing the Results of different models

# %%
df
# Out:
#                  Model  Accuracy  Error Rate
# 0  Logistic Regression    0.9250      0.0750
# 1                  SVM    0.9125      0.0875
# 2           Kernal SVM    0.9500      0.0500
# 3        Decision Tree    0.9000      0.1000
# 4       Random Foresrt    0.9125      0.0875
# 5          Naive Bayes    0.9125      0.0875

# %% [markdown]
# After checking the results of the 6 different models, i choose "KernalL SVM" as the best model for this data with highest accuracy of 95% and error rate of 5% along with satisfactory AUC-ROC Curve
